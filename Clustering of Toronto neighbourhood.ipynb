# %% [markdown]
# Step 1: Import the libraries needed

# %%
import pandas as pd
import numpy as np
# !conda install -c ulmo beautifulsoup4                   
from bs4 import BeautifulSoup
import requests
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                    /failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package requests conflicts for:
# requests
# tensorboard -> requests[version='>=2.21.0|>=2.21.0,<3']
# bokeh -> requests[version='>=1.2.3']
# requests-oauthlib -> requests[version='>=2.0.0']
# ibm-wsrt-py37main-main -> requests==2.24.0[build=*]
# jupyterlab_server -> requests
# plotly -> requests
# nltk -> requests
#
# Package mkl-service conflicts for:
# numpy -> mkl-service[version='>=2,<3.0a0']
# mkl-service
# numpy-base -> mkl-service[version='>=2,<3.0a0']
# numexpr -> mkl-service[version='>=2,<3.0a0']
# scikit-learn -> mkl-service[version='>=2,<3.0a0']
# mkl_fft -> mkl-service[version='>=2,<3.0a0']
# scipy -> mkl-service[version='>=2,<3.0a0']
# pytorch -> mkl-service[version='>=2,<3.0a0']
# ibm-wsrt-py37main-main -> mkl-service==2.3.0[build=*]
# mkl_random -> mkl-service[version='>=2,<3.0a0']
#
# Package libgcc-ng conflicts for:
# matplotlib -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# python=3.7 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# brotlipy -> libgcc-ng[version='>=7.3.0']
# c-ares -> libgcc-ng[version='>=7.3.0']
# libsodium -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# yaml -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyrsistent -> libgcc-ng[version='>=7.3.0']
# freetype -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# sqlalchemy -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# ncurses -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# zlib -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# unixodbc -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# mkl-service -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyodbc -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# cx_oracle -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libtiff -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# yarl -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# gmp -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# xz -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# tornado -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# kiwisolver -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# ibm-wsrt-py37main-main -> libgcc-ng==9.1.0[build=*]
# numpy-base -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# gst-plugins-base -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pytorch -> libgcc-ng[version='>=5.4.0|>=7.3.0']
# libedit -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyqt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# astropy -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# hdf5 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# zeromq -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pcre -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# ninja -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# regex -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# scikit-learn -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# bzip2 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pymssql -> libgcc-ng[version='>=7.3.0']
# multidict -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# matplotlib-base -> libgcc-ng[version='>=7.3.0']
# dbus -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# psycopg2 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libffi -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# protobuf -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# expat -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# jpeg -> libgcc-ng[version='>=7.2.0']
# numexpr -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# tensorflow-base -> libgcc-ng[version='>=5.4.0|>=7.2.0']
# sip -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# fontconfig -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyzmq -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# numpy -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# krb5 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# aiohttp -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# grpcio -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cytoolz -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# lz4-c -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# markupsafe -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libpng -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libxcb -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# py-xgboost -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# glib -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# readline -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# scikit-image -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# lcms2 -> libgcc-ng[version='>=7.3.0']
# tk -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# mistune -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libxgboost -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# pillow -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libprotobuf -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pandas -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# blosc -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# sqlite -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# wrapt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libxslt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# freetds -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libpq -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# openssl -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# lxml -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# gstreamer -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# snappy -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# qt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# fastcache -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# statsmodels -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# biopython -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# zstd -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libuuid -> libgcc-ng[version='>=7.2.0']
# pytables -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyyaml -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# cryptography -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# cffi -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libxml2 -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libgcc-ng
# h5py -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# mkl_random -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pywavelets -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# mkl_fft -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# scipy -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# tensorboard -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# icu -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# lzo -> libgcc-ng[version='>=7.2.0|>=7.3.0']
#
# Package traitlets conflicts for:
# traitlets
# notebook -> traitlets[version='>=4.2.1|>=4.3']
# nbformat -> traitlets[version='>=4.1']
# ipywidgets -> traitlets[version='>=4.3.1|>=4.3.1,<5.0.0|>=4.3.1,<6.0.0']
# ibm-wsrt-py37main-main -> traitlets==4.3.3[build=*]
# jupyter_client -> traitlets
# ipykernel -> traitlets[version='>=4.1']
# ipython -> traitlets[version='>=4.2']
# jupyter_core -> traitlets
# nbconvert -> traitlets[version='>=4.2']
#
# Package xz conflicts for:
# ibm-wsrt-py37main-main -> xz==5.2.5[build=*]
# zstd -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# gst-plugins-base -> xz[version='>=5.2.3,<6.0a0']
# xz
# gstreamer -> xz[version='>=5.2.3,<6.0a0']
# libtiff -> xz[version='>=5.2.3,<6.0a0|>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# python=3.7 -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# libxml2 -> xz[version='>=5.2.3,<6.0a0|>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
#
# Package cryptography conflicts for:
# ibm-wsrt-py37main-main -> cryptography==3.2.1[build=*]
# cryptography
# pyjwt -> cryptography[version='>=1.0|>=1.4|>=2.6,<3.0.0']
# secretstorage -> cryptography
# oauthlib -> cryptography
# urllib3 -> cryptography[version='>=1.3.4']
# google-auth-oauthlib -> cryptography[version='>=3.2']
# pyopenssl -> cryptography[version='>=1.9|>=2.1.4|>=2.2.1|>=2.8']
#
# Package jmespath conflicts for:
# ibm-wsrt-py37main-main -> jmespath==0.9.4[build=*]
# jmespath
# boto3 -> jmespath[version='>=0.7.1,<1.0.0']
# botocore -> jmespath[version='>=0.7.1,<1.0.0']
#
# Package widgetsnbextension conflicts for:
# ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
# widgetsnbextension
# arcgis=1.6.0 -> widgetsnbextension[version='>=3']
# ibm-wsrt-py37main-main -> widgetsnbextension==3.5.1[build=*]
#
# Package h5py conflicts for:
# tensorflow-base -> h5py[version='>=2.10.0,<2.11.0a0']
# ibm-wsrt-py37main-main -> h5py==2.10.0[build=*]
# keras-applications -> h5py
# h5py
#
# Package matplotlib-base conflicts for:
# matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0',build='py37hef1b27d_1|py38hef1b27d_1|py36hef1b27d_1|py38hef1b27d_0|py37hef1b27d_0|py36hef1b27d_0']
# matplotlib-base
# scikit-image -> matplotlib-base[version='>=2.0.0']
# ibm-wsrt-py37main-main -> matplotlib-base==3.2.2[build=*]
#
# Package six conflicts for:
# html5lib -> six[version='>=1.9']
# absl-py -> six
# google-pasta -> six
# cryptography -> six[version='>=1.4.1']
# python-dateutil -> six[version='>=1.5']
# grpcio -> six[version='>=1.5.2']
# tensorflow-base -> six[version='>=1.10.0|>=1.12.0,<2.0a0|>=1.12.0|>=1.15.0']
# more-itertools -> six[version='>=1.0.0,<2.0.0']
# nltk -> six
# tensorflow-estimator -> six[version='>=1.10.0']
# traitlets -> six
# bokeh -> six[version='>=1.5.2']
# bleach -> six
# arcgis=1.6.0 -> six
# pytables -> six
# pytest -> six[version='>=1.10.0']
# jsonschema -> six[version='>=1.11.0']
# six
# protobuf -> six
# scikit-image -> six[version='>=1.7.3']
# tensorboard -> six[version='>=1.10.0|>=1.12']
# keras-preprocessing -> six[version='>=1.9.0']
# pyopenssl -> six[version='>=1.5.2']
# google-auth -> six[version='>=1.9.0']
# prompt-toolkit -> six[version='>=1.9.0']
# mock -> six
# packaging -> six
# pyrsistent -> six
# cycler -> six
# ibm-wsrt-py37main-main -> six==1.15.0[build=*]
# h5py -> six
# patsy -> six
# plotly -> six
# mkl-service -> six
#
# Package sympy conflicts for:
# sympy
# ibm-wsrt-py37main-main -> sympy==1.6.2[build=*]
#
# Package gast conflicts for:
# tensorflow-base -> gast[version='>=0.2.0|>=0.2.2,<0.2.3.0a0|>=0.3.3,<0.3.4.0a0|>=0.4.0,<0.4.1.0a0']
# gast
# ibm-wsrt-py37main-main -> gast==0.2.2[build=*]
#
# Package decorator conflicts for:
# ibm-wsrt-py37main-main -> decorator==4.4.2[build=*]
# traitlets -> decorator
# plotly -> decorator[version='>=4.0.6']
# decorator
# ipython -> decorator
# networkx -> decorator[version='>=3.4.0|>=4.1.0|>=4.3.0']
#
# Package readline conflicts for:
# ibm-wsrt-py37main-main -> readline==8.0[build=*]
# libpq -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0']
# freetds -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0']
# python=3.7 -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0']
# readline
#
# Package pytz conflicts for:
# pandas -> pytz[version='>=2017.2']
# plotly -> pytz
# ibm-wsrt-py37main-main -> pytz==2020.1[build=*]
# pytz
# matplotlib -> pytz
#
# Package blosc conflicts for:
# blosc
# pytables -> blosc[version='>=1.14.3,<2.0a0|>=1.14.4,<2.0a0|>=1.15.0,<2.0a0|>=1.16.3,<2.0a0|>=1.20.1,<2.0a0']
# ibm-wsrt-py37main-main -> blosc==1.19.0[build=*]
#
# Package tensorboard conflicts for:
# ibm-wsrt-py37main-main -> tensorboard==2.1.0[build=*]
# tensorboard
#
# Package absl-py conflicts for:
# absl-py
# tensorflow-base -> absl-py[version='>=0.1.6|>=0.11.0|>=0.7.1|>=0.8.1|>=0.7.1,<1.0a0|>=0.7.0']
# ibm-wsrt-py37main-main -> absl-py==0.9.0[build=*]
# tensorflow-estimator -> absl-py[version='>=0.1.6']
# tensorboard -> absl-py[version='>=0.4|>=0.7']
#
# Package libstdcxx-ng conflicts for:
# scikit-learn -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pyzmq -> libstdcxx-ng[version='>=7.3.0']
# pcre -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# krb5 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# numexpr -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# scipy -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# icu -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# kiwisolver -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# ncurses -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# mkl_random -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# sip -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# tensorflow-base -> libstdcxx-ng[version='>=5.4.0|>=7.2.0']
# matplotlib -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# expat -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# biopython -> libstdcxx-ng[version='>=7.2.0']
# grpcio -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# protobuf -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# glib -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# python=3.7 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# libstdcxx-ng
# qt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# py-xgboost -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# snappy -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# zeromq -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pytorch -> libstdcxx-ng[version='>=5.4.0|>=7.3.0']
# gst-plugins-base -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pandas -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# hdf5 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# ibm-wsrt-py37main-main -> libstdcxx-ng==9.1.0[build=*]
# scikit-image -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# zstd -> libstdcxx-ng[version='>=7.3.0']
# pyodbc -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# lz4-c -> libstdcxx-ng[version='>=7.3.0']
# matplotlib-base -> libstdcxx-ng[version='>=7.3.0']
# libtiff -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pytables -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# libffi -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pyqt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# gmp -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# blosc -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# libxgboost -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# mkl_fft -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# tensorboard -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# libprotobuf -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# ninja -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
#
# Package libffi conflicts for:
# ibm-wsrt-py37main-main -> libffi==3.3[build=*]
# python=3.7 -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# glib -> libffi[version='>=3.0.0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# libffi
# gstreamer -> libffi[version='>=3.2.1,<3.3a0']
# cffi -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
#
# Package multidict conflicts for:
# multidict
# aiohttp -> multidict[version='>=2.1.4|>=3.0.0|>=4.0,<5.0|>=4.5,<5.0|>=4.5,<7.0']
# ibm-wsrt-py37main-main -> multidict==4.7.6[build=*]
# yarl -> multidict[version='>=2.0|>=4.0']
#
# Package zipp conflicts for:
# importlib-metadata -> zipp[version='>=0.5']
# zipp
# importlib_metadata -> zipp[version='>=0.3.2|>=0.5']
# ibm-wsrt-py37main-main -> zipp==3.1.0[build=*]
#
# Package setuptools conflicts for:
# sympy -> setuptools
# protobuf -> setuptools
# bleach -> setuptools
# google-auth -> setuptools[version='>=40.3.0']
# pygments -> setuptools
# plotly -> setuptools
# astropy -> setuptools
# joblib -> setuptools
# wheel -> setuptools
# jsonschema -> setuptools
# markdown -> setuptools
# grpcio -> setuptools
# ibm-wsrt-py37main-main -> setuptools==47.3.1[build=*]
# networkx -> setuptools
# tensorboard -> setuptools[version='>=41.0.0|>=41.4']
# setuptools
# matplotlib -> setuptools
# pip -> setuptools
# matplotlib-base -> setuptools
# jinja2 -> setuptools
# ipython -> setuptools[version='>=18.5']
# pytest -> setuptools[version='>=40.0']
#
# Package yaml conflicts for:
# ibm-wsrt-py37main-main -> yaml==0.2.5[build=*]
# yaml
# pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
#
# Package nbformat conflicts for:
# nbconvert -> nbformat[version='>=4.4']
# nbformat
# notebook -> nbformat
# ibm-wsrt-py37main-main -> nbformat==5.0.7[build=*]
# plotly -> nbformat[version='>=4.2']
# ipywidgets -> nbformat[version='>=4.2.0']
#
# Package ncurses conflicts for:
# libedit -> ncurses[version='6.0.*|>=6.1,<7.0a0|>=6.2,<7.0a0']
# readline -> ncurses[version='6.0.*|>=6.0,<7.0a0|>=6.1,<7.0a0|>=6.2,<7.0a0']
# ibm-wsrt-py37main-main -> ncurses==6.2[build=*]
# sqlite -> ncurses[version='>=6.2,<7.0a0']
# ncurses
# python=3.7 -> ncurses[version='>=6.1,<7.0a0|>=6.2,<7.0a0']
#
# Package openssl conflicts for:
# krb5 -> openssl[version='1.0.*|>=1.0.2l,<1.0.3a|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a']
# freetds -> openssl[version='>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1i,<1.1.2a']
# cryptography -> openssl[version='1.0.*|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.0.2n,<1.0.3a|>=1.0.2m,<1.0.3a']
# libpq -> openssl[version='>=1.0.2m,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1d,<1.1.2a']
# psycopg2 -> openssl[version='1.0.*|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.0.2m,<1.0.3a']
# openssl
# python=3.7 -> openssl[version='>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a']
# qt -> openssl[version='1.0.*|1.1.*|>=1.0.2p,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2n,<1.0.3a']
# ibm-wsrt-py37main-main -> openssl==1.1.1j[build=*]
# grpcio -> openssl[version='>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a']
#
# Package libprotobuf conflicts for:
# ibm-wsrt-py37main-main -> libprotobuf==3.12.3[build=*]
# protobuf -> libprotobuf[version='3.10.1.*|3.11.2.*|3.11.3.*|3.11.4.*|3.12.3.*|3.12.4.*|3.13.0.*|3.13.0.1.*|3.14.0.*|>=3.14.0,<3.15.0a0|>=3.13.0.1,<3.14.0a0|>=3.13.0,<3.14.0a0|>=3.12.4,<3.13.0a0|>=3.12.3,<3.13.0a0|>=3.11.4,<3.12.0a0|>=3.11.3,<3.12.0a0|>=3.11.2,<3.12.0a0|>=3.10.1,<3.11.0a0|3.9.2.*|>=3.9.2,<3.10.0a0|3.8.0.*|>=3.8.0,<3.9.0a0|>=3.7.1,<3.8.0a0|>=3.6.1,<3.6.2.0a0|>=3.6.0,<3.6.1.0a0|>=3.5.2,<3.6.0a0|>=3.5.1,<3.6.0a0|>=3.4.1,<3.5.0a0']
# libprotobuf
#
# Package future conflicts for:
# ibm-wsrt-py37main-main -> future==0.18.2[build=*]
# future
# tensorflow-base -> future
# pytorch -> future
#
# Package prometheus_client conflicts for:
# prometheus_client
# ibm-wsrt-py37main-main -> prometheus_client==0.8.0[build=*]
# notebook -> prometheus_client
#
# Package google-auth-oauthlib conflicts for:
# ibm-wsrt-py37main-main -> google-auth-oauthlib==0.4.1[build=*]
# google-auth-oauthlib
# tensorboard -> google-auth-oauthlib[version='>=0.4.1|>=0.4.1,<0.5']
#
# Package keras-applications conflicts for:
# keras-applications
# tensorflow-base -> keras-applications[version='>=1.0.5|>=1.0.6|>=1.0.8|>=1.0.8,<2.0a0']
# ibm-wsrt-py37main-main -> keras-applications==1.0.8[build=*]
#
# Package protobuf conflicts for:
# ibm-wsrt-py37main-main -> protobuf==3.12.3[build=*]
# tensorflow-base -> protobuf[version='>=3.14.0|>=3.8.0|>=3.9.2|>=3.6.1,<4.0a0|>=3.6.1|>=3.6.0|>=3.4.0|>=3.3.0']
# grpcio -> protobuf[version='>=3.5.0']
# tensorboard -> protobuf[version='>=3.4.0|>=3.6.0|>=3.6.1|>=3.8.0']
# protobuf
#
# Package python-dateutil conflicts for:
# pandas -> python-dateutil[version='>=2.5.*|>=2.6.1|>=2.7.3']
# matplotlib -> python-dateutil
# ibm-wsrt-py37main-main -> python-dateutil==2.8.1[build=*]
# jupyter_client -> python-dateutil[version='>=2.1']
# botocore -> python-dateutil[version='>=2.1,<2.7.0|>=2.1,<2.8.1|>=2.1,<3.0.0']
# python-dateutil
# bokeh -> python-dateutil[version='>=2.1']
# matplotlib-base -> python-dateutil[version='>=2.1']
#
# Package certifi conflicts for:
# ibm-wsrt-py37main-main -> certifi==2020.12.5[build=*]
# matplotlib-base -> certifi[version='>=2020.06.20']
# certifi
# tornado -> certifi
# urllib3 -> certifi
# setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# requests -> certifi[version='>=2017.4.17']
#
# Package cloudpickle conflicts for:
# scikit-image -> cloudpickle[version='>=0.2.1']
# cloudpickle
# ibm-wsrt-py37main-main -> cloudpickle==1.5.0[build=*]
#
# Package jupyter_core conflicts for:
# nbconvert -> jupyter_core
# nbformat -> jupyter_core
# notebook -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# jupyter_client -> jupyter_core[version='>=4.6.0']
# ibm-wsrt-py37main-main -> jupyter_core==4.6.3[build=*]
# jupyter_core
#
# Package psycopg2 conflicts for:
# psycopg2
# ibm-wsrt-py37main-main -> psycopg2==2.8.5[build=*]
#
# Package libpq conflicts for:
# libpq
# psycopg2 -> libpq[version='>=10.3,<11.0a0|>=11.1,<12.0a0|>=11.2,<12.0a0|>=12.2,<13.0a0|>=9.6.6']
# ibm-wsrt-py37main-main -> libpq==12.2[build=*]
#
# Package markdown conflicts for:
# tensorflow-base -> markdown[version='>=2.6.11']
# markdown
# ibm-wsrt-py37main-main -> markdown==3.1.1[build=*]
# tensorboard -> markdown[version='>=2.6.11|>=2.6.8']
#
# Package sip conflicts for:
# ibm-wsrt-py37main-main -> sip==4.19.8[build=*]
# pyqt -> sip[version='4.18.*|4.19.13.*|>=4.19.13,<=4.19.14|>=4.19.4,<=4.19.8']
# sip
#
# Package numpy conflicts for:
# pytorch -> numpy[version='>=1.11|>=1.11.3,<2.0a0|>=1.16.6,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.9']
# tensorboard -> numpy[version='>=1.12|>=1.12.0|>=1.16']
# matplotlib -> numpy[version='>=1.14.6,<2.0a0']
# opt_einsum -> numpy
# pandas -> numpy[version='>=1.11.3,<2.0a0|>=1.12.1,<2.0a0|>=1.13.3,<2.0a0|>=1.14.6,<2.0a0|>=1.15.4,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0|>=1.9']
# tensorflow-base -> numpy[version='>=1.12.1,<2.0a0|>=1.13.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0']
# astropy -> numpy[version='>=1.10.4,<2.0a0|>=1.11.3,<2.0a0|>=1.13.3,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0|>=1.17.0,<2.0a0|>=1.17.4,<2.0a0|>=1.14.6,<2.0a0|>=1.11|>=1.9|>=1.14|>=1.9.3,<2.0a0|>=1.14.1,<2.0a0|>=1.14.0,<2.0a0']
# patsy -> numpy[version='>=1.4.0']
# matplotlib-base -> numpy[version='>=1.14.6,<2.0a0|>=1.15.4,<2.0a0|>=1.16.6,<2.0a0']
# scikit-learn -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0']
# keras-applications -> numpy[version='>=1.9.1']
# ibm-wsrt-py37main-main -> numpy==1.18.5[build=*]
# arcgis=1.6.0 -> numpy
# scipy -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.15.1,<2.0a0|>=1.9.3,<2.0a0']
# pywavelets -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0']
# numexpr -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.16.4,<2.0a0|>=1.15.4,<2.0a0|>=1.9.3,<2.0a0']
# tensorflow-estimator -> numpy[version='>=1.13.3']
# keras-preprocessing -> numpy[version='>=1.9.1']
# statsmodels -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.17.0,<2.0a0|>=1.19.2,<2.0a0|>=1.19.1,<2.0a0|>=1.9.3,<2.0a0']
# numpy
# biopython -> numpy[version='>=1.11.3,<2.0a0|>=1.9.3,<2.0a0|>=1.14.1,<2.0a0']
# h5py -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0']
# mkl_fft -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0']
# nltk -> numpy
# imageio -> numpy
# seaborn -> numpy[version='>=1.13.3|>=1.9.3']
# mkl-service -> numpy[version='>=1.11.3,<2.0a0']
# scikit-image -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0|>=1.13.3,<2.0a0']
# pytables -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0']
# bokeh -> numpy[version='>=1.11.3|>=1.7.1']
# py-xgboost -> numpy
# mkl_random -> numpy[version='>=1.11.3,<2.0a0|>=1.14,<2.0a0|>=1.14.6,<2.0a0']
#
# Package astropy conflicts for:
# ibm-wsrt-py37main-main -> astropy==4.0.1.post1[build=*]
# astropy
#
# Package pytorch conflicts for:
# ibm-wsrt-py37main-main -> pytorch==1.3.1[build=cpu_*]
# pytorch
#
# Package send2trash conflicts for:
# ibm-wsrt-py37main-main -> send2trash==1.5.0[build=*]
# notebook -> send2trash
# send2trash
#
# Package webencodings conflicts for:
# bleach -> webencodings
# webencodings
# ibm-wsrt-py37main-main -> webencodings==0.5.1[build=*]
# tensorboard -> webencodings
# html5lib -> webencodings
#
# Package fontconfig conflicts for:
# fontconfig
# qt -> fontconfig[version='>=2.12.4,<3.0a0|>=2.12.6,<3.0a0|>=2.13.0,<3.0a0']
# ibm-wsrt-py37main-main -> fontconfig==2.13.0[build=*]
#
# Package terminado conflicts for:
# terminado
# notebook -> terminado[version='>=0.3.3|>=0.8.1']
# ibm-wsrt-py37main-main -> terminado==0.8.3[build=*]
#
# Package libxgboost conflicts for:
# py-xgboost -> libxgboost[version='0.7|0.71|0.72|0.72|0.72|0.80|0.80|0.80|0.80|0.90',build='h6cbba54_0|h688424c_0|he6710b0_1|hf484d3e_1|h6edc907_0|h4d71fd4_0|he6710b0_0|h51060c3_0|h6edc907_0|he6710b0_0|h87a4715_0|h83be7fe_0|hf484d3e_0|hf484d3e_0|hf484d3e_0']
# libxgboost
# ibm-wsrt-py37main-main -> libxgboost==0.90[build=*]
#
# Package oauthlib conflicts for:
# ibm-wsrt-py37main-main -> oauthlib==3.1.0[build=*]
# requests-oauthlib -> oauthlib[version='>=0.6.2|>=3.0.0']
# oauthlib
#
# Package ninja conflicts for:
# ibm-wsrt-py37main-main -> ninja==1.9.0[build=*]
# ninja
# pytorch -> ninja
#
# Package testpath conflicts for:
# testpath
# ibm-wsrt-py37main-main -> testpath==0.4.4[build=*]
# nbconvert -> testpath
#
# Package tk conflicts for:
# tk
# ibm-wsrt-py37main-main -> tk==8.6.10[build=*]
# matplotlib -> tk[version='8.6.*|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib-base -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# krb5 -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python=3.7 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
#
# Package aiohttp conflicts for:
# ibm-wsrt-py37main-main -> aiohttp==3.6.2[build=*]
# google-auth -> aiohttp
# aiohttp
#
# Package ld_impl_linux-64 conflicts for:
# ld_impl_linux-64
# ibm-wsrt-py37main-main -> ld_impl_linux-64==2.33.1[build=*]
# python=3.7 -> ld_impl_linux-64
#
# Package pywavelets conflicts for:
# pywavelets
# scikit-image -> pywavelets[version='>=0.4.0']
# ibm-wsrt-py37main-main -> pywavelets==1.1.1[build=*]
#
# Package dbus conflicts for:
# qt -> dbus[version='>=1.10.22,<2.0a0|>=1.12.2,<2.0a0|>=1.13.2,<2.0a0']
# secretstorage -> dbus
# dbus
# ibm-wsrt-py37main-main -> dbus==1.13.16[build=*]
# pyqt -> dbus[version='>=1.10.22,<2.0a0|>=1.12.2,<2.0a0|>=1.13.12,<2.0a0|>=1.13.2,<2.0a0']
#
# Package futures conflicts for:
# grpcio -> futures[version='>=2.2.0']
# imageio -> futures
# jupyterlab -> futures
# s3transfer -> futures[version='>=2.2.0,<4.0.0']
# tensorboard -> futures[version='>=3.1.1']
# bokeh -> futures[version='>=3.0.3']
# tornado -> futures
#
# Package numpy-base conflicts for:
# numpy -> numpy-base[version='1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.11.3|1.14.3|1.14.3|1.14.3|1.14.3|1.14.3|1.14.3|1.14.4|1.14.4|1.14.4|1.14.4|1.14.4|1.14.4|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.5|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.14.6|1.15.0|1.15.0|1.15.0|1.15.0|1.15.0|1.15.0|1.15.0|1.15.0|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.1|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.2|1.15.3|1.15.3|1.15.3|1.15.3|1.15.3|1.15.3|1.15.4|1.15.4|1.15.4|1.15.4|1.15.4|1.15.4|1.15.4|1.15.4|1.15.4|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.0|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.1|1.16.2|1.16.2|1.16.2|1.16.2|1.16.2|1.16.2|1.16.3|1.16.3|1.16.3|1.16.3|1.16.3|1.16.3|1.16.4|1.16.4|1.16.4|1.16.4|1.16.4|1.16.4|1.16.5|1.16.5|1.16.5|1.16.5|1.16.5|1.16.5|1.16.6|1.16.6|1.16.6|1.16.6|1.16.6|1.16.6|1.16.6|1.16.6|1.16.6|1.16.6|1.17.2.*|1.17.3.*|1.17.4.*|1.18.1.*|1.18.5.*|1.19.1|1.19.1|1.19.1|1.19.1|1.19.1|1.19.1|1.19.2|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|1.9.3|>=1.9.3,<2.0a0',build='py36h2b20989_6|py37h2b20989_6|py36hdbf6ddf_6|py27h2b20989_7|py35hdbf6ddf_7|py35h2b20989_7|py37h2b20989_7|py27h2b20989_7|py36h2b20989_7|py36h2b20989_8|py37hdbf6ddf_8|py37h2b20989_8|py27h2b20989_8|py27hdbf6ddf_8|py35hdbf6ddf_8|py35h2b20989_8|py35h3dfced4_9|py27h74e8950_9|py35h74e8950_9|py37h74e8950_9|py35h81de0dd_9|py37h74e8950_10|py35h74e8950_10|py27h74e8950_10|py27h81de0dd_10|py35h81de0dd_10|py27h2f8d375_10|py35h2f8d375_10|py37h2f8d375_11|py36h2f8d375_11|py37hde5b4d6_11|py36h2f8d375_12|py27hde5b4d6_12|py36hde5b4d6_12|py38h2f8d375_12|py36h0ea5e3f_1|py35h9be14a7_1|py27h2b20989_0|py36hdbf6ddf_0|py35hdbf6ddf_0|py27hdbf6ddf_0|py35hdbf6ddf_0|py27hdbf6ddf_1|py37hdbf6ddf_1|py27h2b20989_1|py27hdbf6ddf_2|py37hdbf6ddf_2|py36h2b20989_3|py27h2b20989_4|py37h2b20989_4|py37hdbf6ddf_4|py36h2b20989_4|py36hdbf6ddf_4|py35h2b20989_4|py37h2f8d375_4|py27h2f8d375_4|py35h81de0dd_4|py36h81de0dd_4|py38h2f8d375_4|py37h2f8d375_5|py27h2f8d375_5|py36hde5b4d6_5|py27h7cdd4dd_0|py36h7cdd4dd_0|py37h7cdd4dd_0|py36h3dfced4_0|py37h3dfced4_0|py35h74e8950_0|py27h74e8950_0|py36h74e8950_0|py27h2f8d375_0|py27h2f8d375_0|py36h2f8d375_1|py27h81de0dd_1|py37h81de0dd_1|py27h2f8d375_0|py37h2f8d375_0|py37h2f8d375_0|py36h2f8d375_0|py27h2f8d375_0|py36hde5b4d6_0|py27h2f8d375_0|py37hde5b4d6_0|py36hde5b4d6_0|py37h2f8d375_1|py37hde5b4d6_1|py27hde5b4d6_1|py27h2f8d375_0|py36hde5b4d6_0|py37hde5b4d6_0|py37h2f8d375_1|py36h2f8d375_1|py37hde5b4d6_1|py36hde5b4d6_1|py27hde5b4d6_1|py37h2f8d375_0|py27h2f8d375_0|py37hde5b4d6_0|py27h2f8d375_0|py37hde5b4d6_0|py27h2f8d375_0|py36hde5b4d6_0|py37hde5b4d6_0|py36hde5b4d6_0|py37hde5b4d6_0|py36hde5b4d6_0|py38h2f8d375_0|py38hde5b4d6_0|py27h2f8d375_0|py39hfb011de_1|py37hfa32c7d_0|py38h75fe3a5_0|py36h75fe3a5_0|py37h75fe3a5_0|py37hfa32c7d_0|py38h75fe3a5_0|py36h75fe3a5_0|py39h2ae0177_0|py39h0f7b65f_0|py38hfa32c7d_0|py36hfa32c7d_0|py37h75fe3a5_0|py36hfa32c7d_0|py38hfa32c7d_0|py39h76555f2_1|py27hde5b4d6_0|py36h2f8d375_0|py37h2f8d375_0|py27hde5b4d6_0|py37h2f8d375_0|py27h2f8d375_0|py36h2f8d375_0|py27hde5b4d6_0|py37hde5b4d6_0|py37h2f8d375_0|py36h2f8d375_0|py36hde5b4d6_0|py27hde5b4d6_0|py36h2f8d375_0|py37h2f8d375_0|py36hde5b4d6_0|py27hde5b4d6_0|py36h2f8d375_0|py27h2f8d375_1|py27hde5b4d6_0|py36h2f8d375_0|py37h2f8d375 ...
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0']
# numexpr -> numpy-base[version='>=1.17.3,<2.0a0']
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0']
# numpy-base
# ibm-wsrt-py37main-main -> numpy-base==1.18.5[build=*]
#
# Package more-itertools conflicts for:
# more-itertools
# pytest -> more-itertools[version='>=4.0,<6.0|>=4.0|>=4.0.0']
# ibm-wsrt-py37main-main -> more-itertools==8.4.0[build=*]
# zipp -> more-itertools
#
# Package backcall conflicts for:
# ipython -> backcall
# ibm-wsrt-py37main-main -> backcall==0.2.0[build=*]
# backcall
#
# Package tqdm conflicts for:
# ibm-wsrt-py37main-main -> tqdm==4.47.0[build=*]
# nltk -> tqdm
# tqdm
#
# Package pillow conflicts for:
# matplotlib-base -> pillow[version='>=6.2.0']
# scikit-image -> pillow[version='>=2.1.0|>=4.3.0']
# pillow
# ibm-wsrt-py37main-main -> pillow==7.2.0[build=*]
# imageio -> pillow
# bokeh -> pillow[version='>=4.0|>=7.1.0']
#
# Package pcre conflicts for:
# ibm-wsrt-py37main-main -> pcre==8.44[build=*]
# gstreamer -> pcre[version='>=8.42,<9.0a0']
# pcre
# glib -> pcre[version='>=8.42,<9.0a0|>=8.43,<9.0a0|>=8.44,<9.0a0']
#
# Package ptyprocess conflicts for:
# pexpect -> ptyprocess[version='>=0.5']
# ibm-wsrt-py37main-main -> ptyprocess==0.6.0[build=*]
# ptyprocess
# terminado -> ptyprocess
#
# Package markupsafe conflicts for:
# markupsafe
# jinja2 -> markupsafe[version='>=0.23']
# ibm-wsrt-py37main-main -> markupsafe==1.1.1[build=*]
#
# Package intel-openmp conflicts for:
# mkl -> intel-openmp
# intel-openmp
# ibm-wsrt-py37main-main -> intel-openmp==2020.1[build=*]
#
# Package blinker conflicts for:
# blinker
# oauthlib -> blinker
# ibm-wsrt-py37main-main -> blinker==1.4[build=*]
#
# Package zeromq conflicts for:
# pyzmq -> zeromq[version='4.2.*|>=4.2.3,<4.3|>=4.2.5,<4.2.6.0a0|>=4.3.1,<4.4.0a0|>=4.3.2,<4.4.0a0|>=4.3.3,<4.4.0a0']
# ibm-wsrt-py37main-main -> zeromq==4.3.2[build=*]
# zeromq
#
# Package scipy conflicts for:
# keras-preprocessing -> scipy[version='>=0.14']
# scikit-image -> scipy[version='>=0.17|>=0.19']
# statsmodels -> scipy[version='>=0.14|>=1.0']
# scipy
# scikit-learn -> scipy
# tensorflow-base -> scipy[version='>=1.2.1|>=1.4.1|>=1.6.1']
# py-xgboost -> scipy
# ibm-wsrt-py37main-main -> scipy==1.5.0[build=*]
# nltk -> scipy
# seaborn -> scipy[version='>=0.15.2|>=1.0.1']
# patsy -> scipy
#
# Package libpng conflicts for:
# libpng
# fontconfig -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0']
# matplotlib -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0|>=1.6.35,<1.7.0a0|>=1.6.36,<1.7.0a0|>=1.6.37,<1.7.0a0']
# matplotlib-base -> libpng[version='>=1.6.37,<1.7.0a0']
# freetype -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0|>=1.6.37,<1.7.0a0']
# qt -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0|>=1.6.35,<1.7.0a0']
# ibm-wsrt-py37main-main -> libpng==1.6.37[build=*]
#
# Package typing_extensions conflicts for:
# ibm-wsrt-py37main-main -> typing_extensions==3.7.4.2[build=*]
# typing_extensions
# aiohttp -> typing_extensions[version='>=3.6.5']
# tensorflow-base -> typing_extensions
# bokeh -> typing_extensions[version='>=3.7.4']
#
# Package wrapt conflicts for:
# tensorflow-base -> wrapt[version='>=1.11.1|>=1.11.2,<2.0a0|>=1.11.2|>=1.12.1']
# ibm-wsrt-py37main-main -> wrapt==1.12.1[build=*]
# wrapt
#
# Package lcms2 conflicts for:
# lcms2
# ibm-wsrt-py37main-main -> lcms2==2.11[build=*]
# pillow -> lcms2[version='>=2.11,<3.0a0']
#
# Package click conflicts for:
# click
# nltk -> click
# ibm-wsrt-py37main-main -> click==7.1.2[build=*]
# google-auth-oauthlib -> click
#
# Package jedi conflicts for:
# ipython -> jedi[version='>=0.10,<0.18']
# ibm-wsrt-py37main-main -> jedi==0.17.1[build=*]
# jedi
#
# Package pycparser conflicts for:
# cffi -> pycparser
# pycparser
# ibm-wsrt-py37main-main -> pycparser==2.20[build=*]
#
# Package pathlib2 conflicts for:
# testpath -> pathlib2
# pytest -> pathlib2[version='>=2.2.0']
# pickleshare -> pathlib2
# ipython -> pathlib2
# importlib_metadata -> pathlib2
#
# Package toolz conflicts for:
# scikit-image -> toolz[version='>=0.7.3|>=0.7.4']
# ibm-wsrt-py37main-main -> toolz==0.10.0[build=*]
# toolz
# cytoolz -> toolz[version='>=0.10.0|>=0.8.0']
#
# Package imageio conflicts for:
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0']
# imageio
# ibm-wsrt-py37main-main -> imageio==2.9.0[build=*]
#
# Package yarl conflicts for:
# ibm-wsrt-py37main-main -> yarl==1.5.1[build=*]
# yarl
# aiohttp -> yarl[version='>=0.11|>=1.0,<1.6.0|>=1.0,<2|>=1.0,<2.0']
#
# Package pyqt conflicts for:
# pyqt
# ibm-wsrt-py37main-main -> pyqt==5.9.2[build=*]
# matplotlib -> pyqt[version='5.*|5.9.*|>=5.6,<6.0a0|>=5.9.2,<5.10.0a0|5.6.*']
#
# Package patsy conflicts for:
# seaborn -> patsy
# patsy
# ibm-wsrt-py37main-main -> patsy==0.5.1[build=*]
# statsmodels -> patsy[version='>=0.4.0|>=0.5.1']
#
# Package wcwidth conflicts for:
# pytest -> wcwidth
# prompt-toolkit -> wcwidth
# wcwidth
# ibm-wsrt-py37main-main -> wcwidth==0.2.4[build=*]
#
# Package libedit conflicts for:
# unixodbc -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# ibm-wsrt-py37main-main -> libedit==3.1.20191231[build=*]
# libedit
# krb5 -> libedit[version='>=3.1,<4.0a0|>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20191231,<4.0a0|>=3.1.20181209,<4.0a0|>=3.1.20170329,<4.0a0']
# sqlite -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
#
# Package opt_einsum conflicts for:
# tensorflow-base -> opt_einsum[version='>=2.3.2,<3.0a0|>=2.3.2|>=3.1.0|>=3.1.0,<4.0a0']
# ibm-wsrt-py37main-main -> opt_einsum==3.1.0[build=*]
# opt_einsum
#
# Package qt conflicts for:
# ibm-wsrt-py37main-main -> qt==5.9.7[build=*]
# pyqt -> qt[version='5.6.*|5.9.*|>=5.9.7,<5.10.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0|>=5.6.3,<5.7.0a0']
# qt
#
# Package blas conflicts for:
# mkl_fft -> blas[version='*|1.0',build=mkl]
# pytorch -> blas==1.0=mkl
# numexpr -> blas[version='*|*|1.0|1.0',build='openblas|openblas|mkl|mkl']
# blas
# scikit-learn -> blas[version='*|*|1.0|1.0',build='openblas|openblas|mkl|mkl']
# numpy-base -> blas[version='*|*|1.0|1.0',build='openblas|openblas|mkl|mkl']
# mkl_random -> blas[version='*|1.0',build=mkl]
# numpy -> blas[version='*|*|1.0|1.0',build='openblas|openblas|mkl|mkl']
# scipy -> blas[version='*|*|1.0|1.0',build='openblas|openblas|mkl|mkl']
# mkl-service -> blas==1.0=mkl
# ibm-wsrt-py37main-main -> blas==1.0[build=*]
#
# Package unixodbc conflicts for:
# freetds -> unixodbc[version='>=2.3.5,<2.4.0a0|>=2.3.6,<2.4.0a0|>=2.3.7,<2.4.0a0|>=2.3.9,<2.4.0a0']
# pyodbc -> unixodbc[version='2.3.4.*|>=2.3.6,<2.4.0a0|>=2.3.7,<2.4.0a0|>=2.3.9,<2.4.0a0']
# ibm-wsrt-py37main-main -> unixodbc==2.3.7[build=*]
# unixodbc
#
# Package ipython_genutils conflicts for:
# notebook -> ipython_genutils
# nbformat -> ipython_genutils
# ipython_genutils
# ibm-wsrt-py37main-main -> ipython_genutils==0.2.0[build=*]
# traitlets -> ipython_genutils
#
# Package ca-certificates conflicts for:
# ibm-wsrt-py37main-main -> ca-certificates==2021.1.19[build=*]
# ca-certificates
# openssl -> ca-certificates
#
# Package zlib conflicts for:
# glib -> zlib[version='>=1.2.11,<1.3.0a0']
# hdf5 -> zlib[version='1.2.*|>=1.2.11,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0']
# grpcio -> zlib[version='>=1.2.11,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0']
# python=3.7 -> zlib[version='>=1.2.11,<1.3.0a0']
# zlib
# freetype -> zlib[version='>=1.2.11,<1.3.0a0']
# gst-plugins-base -> zlib[version='>=1.2.11,<1.3.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0']
# tensorflow-base -> zlib[version='>=1.2.11,<1.3.0a0']
# pandoc -> zlib
# qt -> zlib[version='>=1.2.11,<1.3.0a0']
# libpq -> zlib[version='>=1.2.11,<1.3.0a0']
# pytables -> zlib[version='>=1.2.11,<1.3.0a0']
# tk -> zlib[version='>=1.2.11,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# libprotobuf -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib -> zlib[version='>=1.2.11,<1.3.0a0']
# ibm-wsrt-py37main-main -> zlib==1.2.11[build=*]
# zstd -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0']
# blosc -> zlib[version='>=1.2.11,<1.3.0a0']
#
# Package libxml2 conflicts for:
# ibm-wsrt-py37main-main -> libxml2==2.9.10[build=*]
# libxml2
# libxslt -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.7,<2.10.0a0|>=2.9.4,<2.10.0a0']
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.7,<2.10.0a0|>=2.9.4,<2.10.0a0']
# qt -> libxml2[version='>=2.9.7,<2.10.0a0|>=2.9.8,<2.10.0a0']
# lxml -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.9,<2.10.0a0|>=2.9.8,<2.10.0a0|>=2.9.7,<2.10.0a0|>=2.9.4,<2.10.0a0']
#
# Package jupyterlab_server conflicts for:
# ibm-wsrt-py37main-main -> jupyterlab_server==1.1.0[build=*]
# jupyterlab_server
# jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0']
#
# Package libgfortran-ng conflicts for:
# scipy -> libgfortran-ng[version='>=7,<8.0a0|>=7.2.0,<8.0a0']
# ibm-wsrt-py37main-main -> libgfortran-ng==7.3.0[build=*]
# libgfortran-ng
# hdf5 -> libgfortran-ng[version='>=7,<8.0a0|>=7.2.0,<8.0a0']
# numpy -> libgfortran-ng[version='>=7,<8.0a0|>=7.2.0,<8.0a0']
# numpy-base -> libgfortran-ng[version='>=7,<8.0a0']
#
# Package snowballstemmer conflicts for:
# ibm-wsrt-py37main-main -> snowballstemmer==2.0.0[build=*]
# snowballstemmer
#
# Package importlib_metadata conflicts for:
# pytest -> importlib_metadata[version='>=0.12']
# pluggy -> importlib_metadata[version='>=0.12']
# importlib_metadata
# keyring -> importlib_metadata[version='>=1']
# ibm-wsrt-py37main-main -> importlib_metadata==1.6.1[build=*]
# jsonschema -> importlib_metadata
#
# Package wheel conflicts for:
# pip -> wheel
# wheel
# tensorboard -> wheel[version='>=0.26']
# ibm-wsrt-py37main-main -> wheel==0.34.2[build=*]
#
# Package pandas conflicts for:
# bokeh -> pandas
# statsmodels -> pandas[version='>=0.14|>=0.21']
# arcgis=1.6.0 -> pandas[version='>=0.23']
# pandas
# seaborn -> pandas[version='>=0.14.0|>=0.22.0']
# ibm-wsrt-py37main-main -> pandas==1.0.5[build=*]
#
# Package idna conflicts for:
# idna
# cryptography -> idna[version='>=2.1']
# requests -> idna[version='>=2.5,<2.7|>=2.5,<2.8|>=2.5,<2.9|>=2.5,<3']
# ibm-wsrt-py37main-main -> idna==2.9[build=*]
# urllib3 -> idna[version='>=2.0.0']
# yarl -> idna[version='>=2.0']
#
# Package parso conflicts for:
# parso
# ibm-wsrt-py37main-main -> parso==0.7.0[build=*]
# jedi -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
#
# Package cffi conflicts for:
# ibm-wsrt-py37main-main -> cffi==1.14.0[build=*]
# pytorch -> cffi
# cffi
# cryptography -> cffi[version='!=1.11.3,>=1.8|>=1.8|>=1.7']
# brotlipy -> cffi[version='>=1.0.0']
#
# Package cudatoolkit conflicts for:
# tensorflow-base -> cudatoolkit[version='8.0.*|9.0.*|9.2.*|>=10.0.130,<10.1.0a0|>=10.1.243,<10.2.0a0|>=10.1.168,<10.2.0a0|>=9.2,<9.3.0a0|>=9.0,<9.1.0a0']
# py-xgboost -> cudatoolkit[version='8.0.*|>=10.0.130,<10.1.0a0|>=9.0,<9.1.0a0|>=9.2,<9.3.0a0|9.0.*|9.2.*']
# libxgboost -> cudatoolkit[version='8.0.*|>=10.0.130,<10.1.0a0|>=9.0,<9.1.0a0|>=9.2,<9.3.0a0|9.0.*|9.2.*']
# pytorch -> cudatoolkit[version='10.0.*|>=10.0.130,<10.1.0a0|>=10.1.243,<10.2.0a0|>=9.2,<9.3.0a0|9.2.*|>=9.0,<9.1.0a0|>=8.0,<8.1.0a0|9.0.*|8.0.*|7.5.*']
#
# Package biopython conflicts for:
# ibm-wsrt-py37main-main -> biopython==1.77[build=*]
# biopython
#
# Package mkl_fft conflicts for:
# numpy -> mkl_fft[version='>=1.0.4|>=1.0.6,<2.0a0']
# ibm-wsrt-py37main-main -> mkl_fft==1.1.0[build=*]
# mkl_fft
#
# Package nbconvert conflicts for:
# notebook -> nbconvert[version='<6.0']
# nbconvert
# ibm-wsrt-py37main-main -> nbconvert==5.6.1[build=*]
#
# Package chardet conflicts for:
# chardet
# aiohttp -> chardet[version='>=2.0,<4.0']
# requests -> chardet[version='>=3.0.2,<3.1.0|>=3.0.2,<4|>=3.0.2,<5']
# ibm-wsrt-py37main-main -> chardet==3.0.4[build=*]
#
# Package bokeh conflicts for:
# ibm-wsrt-py37main-main -> bokeh==2.1.1[build=*]
# bokeh
#
# Package dask-core conflicts for:
# ibm-wsrt-py37main-main -> dask-core==2.20.0[build=*]
# scikit-image -> dask-core[version='>=0.15|>=0.15.0|>=0.9.0']
# dask-core
#
# Package jpeg conflicts for:
# pillow -> jpeg[version='>=9b,<10a']
# jpeg
# lcms2 -> jpeg[version='>=9b,<10a']
# libtiff -> jpeg[version='>=9b,<10a']
# qt -> jpeg[version='>=9b,<10a']
# ibm-wsrt-py37main-main -> jpeg==9b[build=*]
#
# Package pysocks conflicts for:
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# pysocks
# ibm-wsrt-py37main-main -> pysocks==1.7.1[build=*]
#
# Package mkl_random conflicts for:
# numpy -> mkl_random[version='>=1.0.2,<2.0a0']
# ibm-wsrt-py37main-main -> mkl_random==1.1.1[build=*]
# mkl_random
#
# Package google-pasta conflicts for:
# ibm-wsrt-py37main-main -> google-pasta==0.2.0[build=*]
# tensorflow-base -> google-pasta[version='>=0.1.6|>=0.1.7,<1.0a0|>=0.1.7|>=0.1.8|>=0.2.0']
# google-pasta
#
# Package cudnn conflicts for:
# pytorch -> cudnn[version='5.1.*|6.0.*|>=7.0.0,<=8.0a0|>=7.0.5,<=8.0a0|>=7.1.0,<=8.0a0|>=7.1.3,<8.0a0|>=7.3.0,<=8.0a0|>=7.6,<8.0a0|>=7.6.5,<8.0a0|>=7.6.4,<8.0a0|>=7.3.1,<8.0a0|>=7.1.2,<=8.0a0']
# tensorflow-base -> cudnn[version='>=7.0.0,<=8.0a0|>=7.1.0,<=8.0a0|>=7.2.0,<=8.0a0|>=7.3.1,<8.0a0|>=7.6,<8.0a0|>=7.6.5,<8.0a0|>=7.6.0,<8.0a0|>=7.6.4,<8.0a0|>=7.1.2,<=8.0a0|>=7.0.5,<=8.0a0']
#
# Package libopenblas conflicts for:
# numpy -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# scikit-learn -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.3,<1.0a0']
# numexpr -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# numpy-base -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# scipy -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
#
# Package pandoc conflicts for:
# ibm-wsrt-py37main-main -> pandoc==2.9.2.1[build=*]
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# pandoc
#
# Package jsonschema conflicts for:
# jupyterlab_server -> jsonschema[version='>=3.0.1']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0']
# ibm-wsrt-py37main-main -> jsonschema==3.2.0[build=*]
# jsonschema
#
# Package ipykernel conflicts for:
# notebook -> ipykernel
# ibm-wsrt-py37main-main -> ipykernel==5.3.0[build=*]
# ipykernel
# ipywidgets -> ipykernel[version='>=4.5.1']
#
# Package scikit-image conflicts for:
# ibm-wsrt-py37main-main -> scikit-image==0.16.2[build=*]
# scikit-image
#
# Package requests-oauthlib conflicts for:
# ibm-wsrt-py37main-main -> requests-oauthlib==1.3.0[build=*]
# requests-oauthlib
# google-auth-oauthlib -> requests-oauthlib[version='>=0.7.0']
#
# Package mock conflicts for:
# ibm-wsrt-py37main-main -> mock==4.0.2[build=*]
# tensorflow-base -> mock[version='>=2.0.0|>=2.0.0,<3.0a0']
# pytables -> mock
# tensorflow-estimator -> mock[version='>=2.0.0']
# mock
#
# Package pygments conflicts for:
# pygments
# nbconvert -> pygments[version='>=2.4.1']
# prompt-toolkit -> pygments
# ipython -> pygments
# ibm-wsrt-py37main-main -> pygments==2.6.1[build=*]
#
# Package attrs conflicts for:
# aiohttp -> attrs[version='>=17.3.0|>=17.4.0']
# jsonschema -> attrs[version='>=17.4.0']
# pytest -> attrs[version='>=17.2.0|>=17.4.0|>=19.2.0']
# attrs
# ibm-wsrt-py37main-main -> attrs==19.3.0[build=*]
#
# Package pyjwt conflicts for:
# pyjwt
# oauthlib -> pyjwt[version='>=1.0.0']
# ibm-wsrt-py37main-main -> pyjwt==1.7.1[build=*]
#
# Package google-auth conflicts for:
# google-auth
# tensorboard -> google-auth[version='>=1.6.3|>=1.6.3,<2']
# google-auth-oauthlib -> google-auth
# ibm-wsrt-py37main-main -> google-auth==1.22.0[build=*]
#
# Package pexpect conflicts for:
# ipython -> pexpect[version='>4.3']
# ibm-wsrt-py37main-main -> pexpect==4.8.0[build=*]
# pexpect
#
# Package pandocfilters conflicts for:
# ibm-wsrt-py37main-main -> pandocfilters==1.4.2[build=*]
# pandocfilters
# nbconvert -> pandocfilters[version='>=1.4.1']
#
# Package singledispatch conflicts for:
# tornado -> singledispatch
# nltk -> singledispatch
#
# Package libsodium conflicts for:
# ibm-wsrt-py37main-main -> libsodium==1.0.18[build=*]
# libsodium
# pyzmq -> libsodium[version='>=1.0.16,<1.0.17.0a0']
# zeromq -> libsodium[version='>=1.0.16,<1.0.17.0a0|>=1.0.18,<1.0.19.0a0']
#
# Package pyparsing conflicts for:
# matplotlib -> pyparsing
# ibm-wsrt-py37main-main -> pyparsing==2.4.7[build=*]
# packaging -> pyparsing[version='>=2.0.2']
# pyparsing
# nltk -> pyparsing
# matplotlib-base -> pyparsing[version='>=2.0.3,!=2.0.4,!=2.1.2,!=2.1.6']
#
# Package json5 conflicts for:
# json5
# ibm-wsrt-py37main-main -> json5==0.9.5[build=*]
# jupyterlab_server -> json5
#
# Package _pytorch_select conflicts for:
# _pytorch_select
# pytorch -> _pytorch_select[version='0.1|0.2']
# ibm-wsrt-py37main-main -> _pytorch_select==0.1[build=*]
#
# Package libuuid conflicts for:
# fontconfig -> libuuid[version='>=1.0.3,<2.0a0']
# libuuid
# ibm-wsrt-py37main-main -> libuuid==1.0.3[build=*]
#
# Package libtiff conflicts for:
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0']
# ibm-wsrt-py37main-main -> libtiff==4.1.0[build=*]
# pillow -> libtiff[version='>=4.0.10,<5.0a0|>=4.1.0,<5.0a0|>=4.0.9,<5.0a0|>=4.0.8,<5.0a0']
# libtiff
#
# Package jeepney conflicts for:
# secretstorage -> jeepney[version='>=0.6']
# keyring -> jeepney[version='>=0.4.2']
# ibm-wsrt-py37main-main -> jeepney==0.4.0[build=*]
# jeepney
#
# Package snappy conflicts for:
# ibm-wsrt-py37main-main -> snappy==1.1.8[build=*]
# blosc -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
# snappy
#
# Package icu conflicts for:
# libxslt -> icu[version='>=58.2,<59.0a0']
# fontconfig -> icu[version='>=58.2,<59.0a0']
# ibm-wsrt-py37main-main -> icu==58.2[build=*]
# matplotlib-base -> icu[version='>=58.2,<59.0a0']
# qt -> icu[version='>=58.2,<59.0a0']
# icu
# libxml2 -> icu[version='>=58.2,<59.0a0']
# matplotlib -> icu[version='>=58.2,<59.0a0']
#
# Package grpcio conflicts for:
# tensorboard -> grpcio[version='>=1.14|>=1.24.3|>=1.6.3']
# tensorflow-base -> grpcio[version='>=1.14.1,<2.0a0|>=1.14.1|>=1.16.1|>=1.35.0|>=1.8.6']
# grpcio
# ibm-wsrt-py37main-main -> grpcio==1.27.2[build=*]
#
# Package cytoolz conflicts for:
# cytoolz
# scikit-image -> cytoolz[version='>=0.7.3']
# ibm-wsrt-py37main-main -> cytoolz==0.10.1[build=*]
#
# Package py conflicts for:
# ibm-wsrt-py37main-main -> py==1.8.2[build=*]
# py
# pytest -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
#
# Package matplotlib conflicts for:
# seaborn -> matplotlib[version='>=1.4.3|>=2.1.2']
# matplotlib
# bokeh -> matplotlib
# nltk -> matplotlib
# arcgis=1.6.0 -> matplotlib
# ibm-wsrt-py37main-main -> matplotlib==3.2.2[build=*]
# scikit-image -> matplotlib[version='>=1.3.1|>=2.0.0']
#
# Package sqlite conflicts for:
# sqlite
# python=3.7 -> sqlite[version='>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.33.0,<4.0a0']
# tensorflow-base -> sqlite[version='>=3.33.0,<4.0a0']
# qt -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.3,<4.0a0']
# ibm-wsrt-py37main-main -> sqlite==3.33.0[build=*]
#
# Package packaging conflicts for:
# bokeh -> packaging[version='>=16.8']
# bleach -> packaging
# ibm-wsrt-py37main-main -> packaging==20.4[build=*]
# pytest -> packaging
# packaging
#
# Package pyodbc conflicts for:
# pyodbc
# ibm-wsrt-py37main-main -> pyodbc==4.0.30[build=*]
#
# Package cachetools conflicts for:
# cachetools
# ibm-wsrt-py37main-main -> cachetools==4.1.1[build=*]
# google-auth -> cachetools[version='>=2.0.0,<5.0']
#
# Package kiwisolver conflicts for:
# ibm-wsrt-py37main-main -> kiwisolver==1.2.0[build=*]
# matplotlib -> kiwisolver
# matplotlib-base -> kiwisolver[version='>=1.0.1']
# kiwisolver
#
# Package typing-extensions conflicts for:
# ...
# s3transfer -> botocore[version='>=1.12.36,<2.0.0|>=1.12.36,<2.0a.0|>=1.3.0,<2.0.0']
#
# Package jupyterlab conflicts for:
# ibm-wsrt-py37main-main -> jupyterlab==2.2.6[build=*]
# arcgis=1.6.0 -> jupyterlab
# jupyterlab
#
# Package gmp conflicts for:
# gmp
# ibm-wsrt-py37main-main -> gmp==6.1.2[build=*]
# pandoc -> gmp
#
# Package pluggy conflicts for:
# ibm-wsrt-py37main-main -> pluggy==0.13.1[build=*]
# pluggy
# pytest -> pluggy[version='>=0.12,<1.0|>=0.12,<1.0.0a1|>=0.9,!=0.10,<1.0|>=0.9|>=0.7|>=0.5,<0.7']
#
# Package regex conflicts for:
# nltk -> regex
# ibm-wsrt-py37main-main -> regex==2020.6.8[build=*]
# regex
#
# Package lzo conflicts for:
# ibm-wsrt-py37main-main -> lzo==2.10[build=*]
# pytables -> lzo[version='2.*|>=2.10,<3.0a0']
# lzo
#
# Package sqlalchemy conflicts for:
# sqlalchemy
# ibm-wsrt-py37main-main -> sqlalchemy==1.3.17[build=*]
#
# Package krb5 conflicts for:
# krb5
# freetds -> krb5[version='>=1.18.2,<1.19.0a0']
# libpq -> krb5[version='>=1.14.2,<1.15.0a0|>=1.16,<1.17.0a0|>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0']
# ibm-wsrt-py37main-main -> krb5==1.17.1[build=*]
#
# Package mistune conflicts for:
# ibm-wsrt-py37main-main -> mistune==0.8.4[build=*]
# mistune
# nbconvert -> mistune[version='>0.6|>=0.8.1']
#
# Package tornado conflicts for:
# jupyterlab -> tornado[version='!=6.0.0,!=6.0.1,!=6.0.2']
# matplotlib-base -> tornado
# notebook -> tornado[version='>=4,<6|>=4.1,<7|>=5.0|>=5.0,<7']
# terminado -> tornado[version='>=4']
# ipykernel -> tornado[version='>=4.0|>=4.2']
# tornado
# jupyter_client -> tornado[version='>=4.1']
# bokeh -> tornado[version='>=4.3|>=5|>=5.1']
# matplotlib -> tornado
# ibm-wsrt-py37main-main -> tornado==6.0.4[build=*]
#
# Package pyasn1-modules conflicts for:
# pyasn1-modules
# ibm-wsrt-py37main-main -> pyasn1-modules==0.2.8[build=*]
# google-auth -> pyasn1-modules[version='>=0.2.1']
#
# Package glib conflicts for:
# dbus -> glib[version='>=2.53.6,<3.0a0|>=2.56.1,<3.0a0|>=2.56.2,<3.0a0|>=2.63.1,<3.0a0']
# gst-plugins-base -> glib[version='>=2.53.6,<3.0a0|>=2.56.1,<3.0a0|>=2.66.1,<3.0a0']
# ibm-wsrt-py37main-main -> glib==2.65.0[build=*]
# qt -> glib[version='>=2.53.6,<3.0a0|>=2.56.1,<3.0a0|>=2.56.2,<3.0a0']
# glib
# gstreamer -> glib[version='>=2.53.6,<3.0a0|>=2.56.1,<3.0a0|>=2.66.1,<3.0a0']
#
# Package backports.functools_lru_cache conflicts for:
# matplotlib -> backports.functools_lru_cache
# soupsieve -> backports.functools_lru_cache
#
# Package brotlipy conflicts for:
# ibm-wsrt-py37main-main -> brotlipy==0.7.0[build=*]
# brotlipy
# urllib3 -> brotlipy[version='>=0.6.0']
#
# Package termcolor conflicts for:
# ibm-wsrt-py37main-main -> termcolor==1.1.0[build=*]
# tensorflow-base -> termcolor[version='>=1.1.0|>=1.1.0,<2.0a0']
# termcolor
#
# Package werkzeug conflicts for:
# werkzeug
# ibm-wsrt-py37main-main -> werkzeug==1.0.1[build=*]
# tensorboard -> werkzeug[version='>=0.11.10|>=0.11.15|>=0.14']
# tensorflow-base -> werkzeug[version='>=0.14.1,<1.0a0']
#
# Package async-timeout conflicts for:
# aiohttp -> async-timeout[version='<4.0,>=3.0|>=3.0,<4.0|>=1.2,<3.0|>=1.2.0']
# async-timeout
# ibm-wsrt-py37main-main -> async-timeout==3.0.1[build=*]
#
# Package zstd conflicts for:
# zstd
# blosc -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.5.0a0|>=1.4.5,<1.4.6.0a0']
# ibm-wsrt-py37main-main -> zstd==1.4.4[build=*]
# libtiff -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4|>=1.4.4,<1.5.0a0']
#
# Package plotly conflicts for:
# plotly
# ibm-wsrt-py37main-main -> plotly==4.8.2[build=*]
#
# Package jinja2 conflicts for:
# notebook -> jinja2
# jinja2
# ibm-wsrt-py37main-main -> jinja2==2.11.2[build=*]
# bokeh -> jinja2[version='>=2.7']
# jupyterlab_server -> jinja2[version='>2.10*|>=2.10']
# jupyterlab -> jinja2[version='>=2.10']
# nbconvert -> jinja2[version='>=2.4']
#
# Package pip conflicts for:
# pip
# python=3.7 -> pip
# ibm-wsrt-py37main-main -> pip==20.1.1[build=*]
#
# Package pyyaml conflicts for:
# dask-core -> pyyaml
# ibm-wsrt-py37main-main -> pyyaml==5.3.1[build=*]
# pyyaml
# bokeh -> pyyaml[version='>=3.10']
#
# Package scikit-learn conflicts for:
# ibm-wsrt-py37main-main -> scikit-learn==0.23.1[build=*]
# scikit-learn
# nltk -> scikit-learn
# py-xgboost -> scikit-learn
#
# Package ipython conflicts for:
# ibm-wsrt-py37main-main -> ipython==7.15.0[build=*]
# ipython
# ipywidgets -> ipython[version='>=4.0.0']
# ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0']
#
# Package pyopenssl conflicts for:
# urllib3 -> pyopenssl[version='>=0.14']
# pyopenssl
# ibm-wsrt-py37main-main -> pyopenssl==19.1.0[build=*]
#
# Package mpmath conflicts for:
# mpmath
# sympy -> mpmath[version='>=0.19']
# ibm-wsrt-py37main-main -> mpmath==1.1.0[build=*]
#
# Package mkl conflicts for:
# ibm-wsrt-py37main-main -> mkl==2020.1[build=*]
# scikit-learn -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.3,<2021.0a0|>=2019.4,<2021.0a0']
# numexpr -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.1,<2019.0a0|>=2018.0.2,<2019.0a0|>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.4,<2021.0a0']
# mkl_random -> mkl[version='>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.4,<2021.0a0|>=2020.1,<2021.0a0']
# mkl_fft -> mkl[version='>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.3,<2021.0a0|>=2019.4,<2021.0a0']
# mkl-service -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.3,<2021.0a0|>=2019.4,<2021.0a0']
# numpy -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.1,<2019.0a0|>=2018.0.2,<2019.0a0|>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.3,<2021.0a0|>=2019.4,<2021.0a0']
# mkl
# tensorflow-base -> mkl[version='>=2018.0.2,<2019.0a0']
# scipy -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.2,<2019.0a0|>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.4,<2021.0a0']
# numpy-base -> mkl[version='>=2018.0.2,<2019.0a0|>=2018.0.3,<2019.0a0|>=2019.1,<2021.0a0|>=2019.3,<2021.0a0|>=2019.4,<2021.0a0']
# pytorch -> mkl[version='2019.*|2020.*|>=2020.2,<2021.0a0|>=2019.4,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.2,<2019.0a0']
#
# Package pyrsistent conflicts for:
# ibm-wsrt-py37main-main -> pyrsistent==0.16.0[build=*]
# pyrsistent
# jsonschema -> pyrsistent[version='>=0.14.0']
#
# Package astor conflicts for:
# astor
# tensorflow-base -> astor[version='>=0.6.0|>=0.6.2|>=0.6.2,<1.0a0']
# ibm-wsrt-py37main-main -> astor==0.8.0[build=*]
#
# Package retrying conflicts for:
# plotly -> retrying[version='>=1.3.3']
# retrying
# ibm-wsrt-py37main-main -> retrying==1.3.3[build=*]
#
# Package pyshp conflicts for:
# ibm-wsrt-py37main-main -> pyshp==2.1.0[build=*]
# pyshp
# arcgis=1.6.0 -> pyshp
#
# Package bleach conflicts for:
# ibm-wsrt-py37main-main -> bleach==3.1.5[build=*]
# bleach
# tensorboard -> bleach[version='1.5.0|>=1.5.0,<1.5.1.0a0']
# nbconvert -> bleach
#
# Package tensorflow-base conflicts for:
# tensorflow-estimator -> tensorflow-base[version='>=1.14.0,<1.15.0a0|>=1.15.0,<1.16.0a0|>=2.0.0,<2.1.0a0|>=2.1.0,<2.2.0a0|>=2.2.0,<2.3.0a0|>=2.3.0,<2.4.0a0|>=2.4.1,<2.5.0a0']
# tensorflow-base
# ibm-wsrt-py37main-main -> tensorflow-base==2.1.0[build=*]
#
# Package olefile conflicts for:
# pillow -> olefile
# olefile
# ibm-wsrt-py37main-main -> olefile==0.46[build=*]
#
# Package configparser conflicts for:
# importlib_metadata -> configparser[version='>=3.5']
# entrypoints -> configparser
#
# Package docutils conflicts for:
# docutils
# ibm-wsrt-py37main-main -> docutils==0.15.2[build=*]
# botocore -> docutils[version='>=0.10|>=0.10,<0.15|>=0.10,<0.16']
#
# Package keras-preprocessing conflicts for:
# keras-preprocessing
# ibm-wsrt-py37main-main -> keras-preprocessing==1.1.0[build=*]
# tensorflow-base -> keras-preprocessing[version='>=1.0.3|>=1.0.5|>=1.0.5,<2.0a0|>=1.1.0|>=1.1.2']
#
# Package rsa conflicts for:
# google-auth -> rsa[version='>=3.1.4,<4.1|>=3.1.4,<5']
# ibm-wsrt-py37main-main -> rsa==4.6[build=*]
# rsa
#
# Package enum34 conflicts for:
# tensorflow-base -> enum34[version='>=1.1.6|>=1.1.6,<2.0a0']
# imageio -> enum34
# traitlets -> enum34
# cryptography -> enum34
# absl-py -> enum34
# grpcio -> enum34[version='>=1.0.4']
#
# Package pytables conflicts for:
# ibm-wsrt-py37main-main -> pytables==3.6.1[build=*]
# pytables
#
# Package funcsigs conflicts for:
# mock -> funcsigs
# pytest -> funcsigs[version='>=1.0']
#
# Package notebook conflicts for:
# notebook
# ibm-wsrt-py37main-main -> notebook==6.0.3[build=*]
# jupyterlab -> notebook[version='>=4.3|>=4.3.1']
# jupyterlab_server -> notebook[version='>=4.2.0']
# widgetsnbextension -> notebook[version='>=4.4.1']
# arcgis=1.6.0 -> notebook
#
# Package subprocess32 conflicts for:
# jupyterlab -> subprocess32
# matplotlib -> subprocess32
#
# Package libxcb conflicts for:
# qt -> libxcb[version='>=1.12,<2.0a0|>=1.13,<2.0a0']
# libxcb
# ibm-wsrt-py37main-main -> libxcb==1.14[build=*]
# gst-plugins-base -> libxcb[version='>=1.12,<2.0a0|>=1.13,<2.0a0|>=1.14,<2.0a0']
#
# Package nltk conflicts for:
# nltk
# ibm-wsrt-py37main-main -> nltk==3.5.0[build=*]
#
# Package urllib3 conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
# urllib3
# botocore -> urllib3[version='>=1.20,<1.24|>=1.20,<1.25|>=1.20,<1.26|>=1.25.4,<1.27']
# ibm-wsrt-py37main-main -> urllib3==1.25.9[build=*]
#
# Package entrypoints conflicts for:
# jupyter_client -> entrypoints
# nbconvert -> entrypoints[version='>=0.2.2']
# entrypoints
# ibm-wsrt-py37main-main -> entrypoints==0.3[build=*]
# keyring -> entrypoints
#
# Package fastcache conflicts for:
# fastcache
# sympy -> fastcache
# ibm-wsrt-py37main-main -> fastcache==1.1.0[build=*]
#
# Package hdf5 conflicts for:
# pytables -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.20,<1.9.0a0|>=1.8.18,<1.8.19.0a0']
# ibm-wsrt-py37main-main -> hdf5==1.10.4[build=*]
# h5py -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.20,<1.9.0a0|>=1.8.18,<1.8.19.0a0']
# hdf5
#
# Package freetype conflicts for:
# pillow -> freetype[version='>=2.10.3,<3.0a0|>=2.10.4,<3.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0']
# matplotlib -> freetype[version='>=2.8,<2.9.0a0|>=2.9.1,<3.0a0']
# freetype
# ibm-wsrt-py37main-main -> freetype==2.10.2[build=*]
# qt -> freetype[version='>=2.8,<2.9.0a0|>=2.9.1,<3.0a0']
# matplotlib-base -> freetype[version='>=2.10.2,<3.0a0|>=2.10.4,<3.0a0|>=2.9.1,<3.0a0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0|>=2.9.1,<3.0a0|>=2.9,<3.0a0|>=2.8,<2.9.0a0']
#
# Package defusedxml conflicts for:
# nbconvert -> defusedxml
# defusedxml
# ibm-wsrt-py37main-main -> defusedxml==0.6.0[build=*]
#
# Package _py-xgboost-mutex conflicts for:
# _py-xgboost-mutex
# py-xgboost -> _py-xgboost-mutex[version='1.0|2.0',build='gpu_0|cpu_0']
# ibm-wsrt-py37main-main -> _py-xgboost-mutex==2.0=cpu_0
#
# Package pyasn1 conflicts for:
# pyasn1-modules -> pyasn1[version='>=0.4.1,<0.5.0|>=0.4.6,<0.5.0']
# ibm-wsrt-py37main-main -> pyasn1==0.4.8[build=*]
# pyasn1
# rsa -> pyasn1[version='>=0.1.3']
#
# Package pickleshare conflicts for:
# ipython -> pickleshare
# pickleshare
# ibm-wsrt-py37main-main -> pickleshare==0.7.5[build=*]
#
# Package lz4-c conflicts for:
# zstd -> lz4-c[version='>=1.9.2,<1.10.0a0']
# blosc -> lz4-c[version='>=1.8.1.2,<1.9.0a0|>=1.9.2,<1.10.0a0|>=1.9.3,<1.10.0a0']
# ibm-wsrt-py37main-main -> lz4-c==1.9.2[build=*]
# lz4-c
#
# Package prompt-toolkit conflicts for:
# ibm-wsrt-py37main-main -> prompt-toolkit==3.0.5[build=*]
# ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0']
# prompt-toolkit
#
# Package boto3 conflicts for:
# ibm-wsrt-py37main-main -> boto3==1.13.11[build=*]
# boto3
#
# Package pytest conflicts for:
# astropy -> pytest[version='<3.7|<4']
# pytest
# ibm-wsrt-py37main-main -> pytest==5.4.3[build=*]
#
# Package xlsxwriter conflicts for:
# xlsxwriter
# ibm-wsrt-py37main-main -> xlsxwriter==1.2.9[build=*]
#
# Package libxslt conflicts for:
# lxml -> libxslt[version='>=1.1.32,<2.0a0|>=1.1.33,<2.0a0|>=1.1.34,<2.0a0']
# ibm-wsrt-py37main-main -> libxslt==1.1.34[build=*]
# libxslt
#
# Package freetds conflicts for:
# freetds
# ibm-wsrt-py37main-main -> freetds==1.00.97[build=*]
# pymssql -> freetds[version='>=1.0.91,<2.0a0|>=1.0.97,<2.0a0']
#
# Package threadpoolctl conflicts for:
# ibm-wsrt-py37main-main -> threadpoolctl==2.1.0[build=*]
# scikit-learn -> threadpoolctl
# threadpoolctl
#
# Package cycler conflicts for:
# matplotlib-base -> cycler[version='>=0.10']
# matplotlib -> cycler[version='>=0.10']
# ibm-wsrt-py37main-main -> cycler==0.10.0[build=*]
# cycler
#
# Package jupyter_client conflicts for:
# ipykernel -> jupyter_client
# ibm-wsrt-py37main-main -> jupyter_client==6.1.3[build=*]
# jupyter_client
# nbconvert -> jupyter_client[version='>=4.2']
# notebook -> jupyter_client[version='>=5.2.0|>=5.3.1|>=5.3.4']
#
# Package pyzmq conflicts for:
# ibm-wsrt-py37main-main -> pyzmq==19.0.1[build=*]
# jupyter_client -> pyzmq[version='>=13']
# pyzmq
# notebook -> pyzmq[version='>=17']
#
# Package bzip2 conflicts for:
# bzip2
# pytables -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ibm-wsrt-py37main-main -> bzip2==1.0.8[build=*]
#
# Package gst-plugins-base conflicts for:
# qt -> gst-plugins-base[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0']
# gst-plugins-base
# ibm-wsrt-py37main-main -> gst-plugins-base==1.14.0[build=*]
#
# Package dill conflicts for:
# ibm-wsrt-py37main-main -> dill==0.3.0[build=*]
# dill
#
# Package pymssql conflicts for:
# pymssql
# ibm-wsrt-py37main-main -> pymssql==2.1.5[build=*]
#
# Package numexpr conflicts for:
# pytables -> numexpr
# ibm-wsrt-py37main-main -> numexpr==2.7.1[build=*]
# numexpr
#
# Package ipaddress conflicts for:
# urllib3 -> ipaddress
# cryptography -> ipaddress
# notebook -> ipaddress
#
# Package soupsieve conflicts for:
# ibm-wsrt-py37main-main -> soupsieve==2.0.1[build=*]
# beautifulsoup4 -> soupsieve[version='>=1.2']
# soupsieve
#
# Package xlrd conflicts for:
# xlrd
# ibm-wsrt-py37main-main -> xlrd==1.2.0[build=*]
#
# Package statsmodels conflicts for:
# ibm-wsrt-py37main-main -> statsmodels==0.11.1[build=*]
# statsmodels
# seaborn -> statsmodels[version='>=0.5.0']
#
# Package html5lib conflicts for:
# bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
# html5lib
# tensorboard -> html5lib[version='0.9999999|>=0.9999999,<0.10000000.0a0']
# ibm-wsrt-py37main-main -> html5lib==1.1.0[build=*]
#
# Package s3transfer conflicts for:
# boto3 -> s3transfer[version='>=0.1.10,<0.2.0|>=0.2.0,<0.3.0|>=0.3.0,<0.4.0']
# ibm-wsrt-py37main-main -> s3transfer==0.3.3[build=*]
# s3transfer
#
# Package c-ares conflicts for:
# grpcio -> c-ares[version='>=1.15.0,<2.0a0|>=1.17.1,<2.0a0']
# ibm-wsrt-py37main-main -> c-ares==1.15.0[build=*]
# c-ares
#
# Package py-xgboost conflicts for:
# py-xgboost
# ibm-wsrt-py37main-main -> py-xgboost==0.90[build=*]
#
# Package cx_oracle conflicts for:
# cx_oracle
# ibm-wsrt-py37main-main -> cx_oracle==7.2.3[build=*]
#
# Package lxml conflicts for:
# ibm-wsrt-py37main-main -> lxml==4.5.1[build=*]
# lxml
#
# Package _libgcc_mutex conflicts for:
# libgcc-ng -> _libgcc_mutex=[build=main]
# _libgcc_mutex
# ibm-wsrt-py37main-main -> _libgcc_mutex==0.1[build=*]
#
# Package seaborn conflicts for:
# seaborn
# ibm-wsrt-py37main-main -> seaborn==0.10.1[build=*]
#
# Package tabulate conflicts for:
# tabulate
# ibm-wsrt-py37main-main -> tabulate==0.8.3[build=*]
#
# Package typing conflicts for:
# pytorch -> typing
# typing_extensions -> typing[version='>=3.7.4']
#
# Package keyring conflicts for:
# arcgis=1.6.0 -> keyring
# ibm-wsrt-py37main-main -> keyring==18.0.0[build=*]
# keyring
# Note that strict channel priority may have removed packages required for satisfiability.

# %% [markdown]
# Step 2: Import the data from the webpage

# %%
# To fetch the data from the link
Link ="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

data= requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

soup = BeautifulSoup(data, 'lxml')

# %% [markdown]
# Step 3: Form the dataframe

# %%
# initiating lists that will be used to create dataframe
postalCodeList = []
boroughList = []
neighborhoodList = []

# looking for the necessary information we need to create our dataframe
for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        postalCodeList.append(cells[0].text.rstrip('\n'))
        boroughList.append(cells[1].text.rstrip('\n'))
        neighborhoodList.append(cells[2].text.rstrip('\n'))
        
# creating the dataframe with the columns we want using pandas
df1 = pd.DataFrame({"PostalCode": postalCodeList,
                           "Borough": boroughList,
                           "Neighborhood": neighborhoodList})

df1.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Step 4: Clean the dataframe

# %%
# Filter all unassigned neighbourhoods
df1 = df1[(df1.Borough.notnull())]
df1 = df1[(df1.Borough != "Not assigned")]

# Group by PostalCode/Borough
df1 = pd.DataFrame(df1.groupby(['PostalCode', 'Borough'])['Neighborhood'].apply(list)).reset_index()
df1['Neighborhood'] = df1['Neighborhood'].apply(lambda x: ', '.join(x))

# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough
df1.loc[ (df1.Neighborhood.isnull() == True) |
               (df1.Neighborhood == "Not assigned")
               , 'Neighborhood'] = df1.Borough

df1.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
df1.shape
# Out:
# (103, 3)

# %% [markdown]
# Step 5: Import the latitude and longitude data for the postal codes

# %%
#using the Geospatial_Coordinates.csv to get respective coordinates for each postal code
df_coor = pd.read_csv('https://cocl.us/Geospatial_data')
df_coor.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Step 6: Merge the longitude and latitude data with the dataframe created

# %%
df2=pd.merge(df1, df_coor, how='left', left_on = 'PostalCode', right_on = 'Postal Code')
df2.drop("Postal Code",axis=1,inplace=True)
df2.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# Step 7: Get the dataframe with the Borough containing "Toronto"

# %%
df3=df2[df2['Borough'].str.contains('Toronto',regex=False)]
df3.head()
# Out:
#    PostalCode          Borough                    Neighborhood   Latitude  \
# 37        M4E     East Toronto                     The Beaches  43.676357
# 41        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 42        M4L     East Toronto  India Bazaar, The Beaches West  43.668999
# 43        M4M     East Toronto                 Studio District  43.659526
# 44        M4N  Central Toronto                   Lawrence Park  43.728020
#
#     Longitude
# 37 -79.293031
# 41 -79.352188
# 42 -79.315572
# 43 -79.340923
# 44 -79.388790

# %% [markdown]
# Step 8: Create a map of the neighbourhoods

# %%
# !pip install folium
import folium
from IPython.display import Image 
from IPython.core.display import HTML 
from IPython.display import display_html

map_toronto = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

for lat,lng,borough,neighbourhood in zip(df3['Latitude'],df3['Longitude'],df3['Borough'],df3['Neighborhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9afd83338c2d408ca78b9837a1f313a1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9afd83338c2d408ca78b9837a1f313a1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9afd83338c2d408ca78b9837a1f313a1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9afd83338c2d408ca78b9837a1f313a1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.65107%2C%20-79.347015%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Step 9: Cluster the neighourhood

# %%
from sklearn.cluster import KMeans
k=5
toronto_clustering = df3.drop(['PostalCode','Borough','Neighborhood'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(toronto_clustering)
kmeans.labels_
# Out:
# array([4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        3, 3, 1, 1, 1, 2, 2, 2, 1, 0, 1, 1, 0, 0, 0, 0, 2, 4], dtype=int32)

# %% [markdown]
# Step 10: Create the map with the clusters formed

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood, cluster in zip(df3['Latitude'], df3['Longitude'], df3['Neighborhood'], df3['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ce23862b4f4143d0a8487ce1b5c20319%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ce23862b4f4143d0a8487ce1b5c20319%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ce23862b4f4143d0a8487ce1b5c20319%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ce23862b4f4143d0a8487ce1b5c20319%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.65107%2C%20-79.347015%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
